# %% [markdown]
# # NETFLIX

# %% [markdown]
# # Overview
# The netflix.csv document contains a dataset of content available on Netflix, including both movies and TV shows. The dataset includes various attributes for each title, such as a unique identifier (show_id), the type of content (type), the title (title), and the director (director). It also lists the main cast members (cast), the country where the content was produced (country), the date it was added to Netflix (date_added), and the year of release (release_year). Additionally, the dataset provides the content rating (rating), the duration (in minutes for movies or number of seasons for TV shows), and the genres or categories the content belongs to (listed_in). The description column offers a brief overview of the content.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
data=pd.read_csv("netflix.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # About Data

# %% [markdown]
# #### Column Descriptions:
#         show_id: unique id given for shows
#         type: the type of media
#         title: the title of the media
#         director: director of the media
#         cast: actors/actresses involved in the show
#         country: country where released
#         date_added: date of release
#         release_year: year of release
#         rating: rating of the show
#         duration: total running time
#         listed_in: the genre of the media
#         description: a little description on the media

# %% [markdown]
# # Data Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.size
# Out:
# 105684

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.dropna(inplace=True)
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %% [markdown]
# # Checking Duplicates

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(8,7))
sns.boxplot(data=data)
plt.show()

# %%
for i in data.columns:
    print(i,':',data[i].nunique())
# Out:
# show_id : 5332
# type : 2
# title : 5332
# director : 3945
# cast : 5200
# country : 604
# date_added : 1453
# release_year : 72
# rating : 14
# duration : 198
# listed_in : 335
# description : 5321

# %%
def split(x):
    return x.split(',')[0]

# %%
data['genre']=data['listed_in'].apply(split)
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data['main lead']=data['cast'].apply(split)
data
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.assign(cast=data['cast'].str.split(',')).explode('cast')
# Out:
#      show_id   type    title      director                    cast  \
# 7         s8  Movie  Sankofa  Haile Gerima            Kofi Ghanaba
# 7         s8  Movie  Sankofa  Haile Gerima     Oyafunmike Ogunlano
# 7         s8  Movie  Sankofa  Haile Gerima          Alexandra Duah
# 7         s8  Movie  Sankofa  Haile Gerima             Nick Medley
# 7         s8  Movie  Sankofa  Haile Gerima              Mutabaruka
# ...      ...    ...      ...           ...                     ...
# 8806   s8807  Movie   Zubaan   Mozez Singh        Manish Chaudhary
# 8806   s8807  Movie   Zubaan   Mozez Singh            Meghna Malik
# 8806   s8807  Movie   Zubaan   Mozez Singh           Malkeet Rauni
# 8806   s8807  Movie   Zubaan   Mozez Singh          Anita Shabdish
# 8806   s8807  Movie   Zubaan   Mozez Singh   Chittaranjan Tripathy
#
#                                                 country          date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %% [markdown]
# # Data Visualization

# %%
data['type'].value_counts().plot(kind='bar',color='red',edgecolor='black');
plt.title('Media shows on netflix');

# %% [markdown]
# * in the given data, number of movies are the highest when compared to TV shows

# %%
data['director'].value_counts().head(10).plot(kind='bar');
plt.title('the directors');

# %% [markdown]
# * Raul Campus has directed more shows when compared to other directors

# %%
data['genre'].value_counts().head(10).plot(kind='bar',color='violet');
plt.title('the distribution of genres');

# %% [markdown]
# * Shows and movies are more of Drama genre whereas Classic movies genre are at the least

# %%
data['release_year'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%');
plt.title('movies released in each year');

# %% [markdown]
# * More number of movies are released in the year 2017 against 2021 and 2012 with the least count of movie releases among the top 10

# %%
data['country'].value_counts().head(10).plot(kind='barh',color='pink');
plt.title('No. of films released in each country');

# %% [markdown]
# * among the top 10 countries of netflix movies and shows, US has topped with huge number of movies and India on the second position

# %%
data['rating'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%');
plt.title('% of films under each rating labels');

# %% [markdown]
# * most of the shows and films fall under TV-MA and TV-14 category of ratings

# %%
def convert (date_added):
    return pd.to_datetime(date_added)
    
data['date_added']=data['date_added'].apply(convert)

# %%
data['date_added_year']=data['date_added'].dt.year

# %%
sns.jointplot(x='date_added_year',y='release_year',data=data,kind='scatter');
plt.title('distribution and relationship of release year and date added to netflix')
# Out:
# Text(0.5, 1.0, 'distribution and relationship of release year and date added to netflix')

# %% [markdown]
# * there is a clustering of data points around recent years, suggesting that most movies and shows are added to Netflix within few years of their original release

# %%
movies_df=data[data['type']=='Movie']

# %%
def split(x):
    return x.split(' ')[0]

# %%
movies_df['duration']=movies_df['duration'].apply(split)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6824\448330257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df['duration']=movies_df['duration'].apply(split)

# %%
movies_df['duration']=movies_df['duration'].astype('int64')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6824\3481371308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df['duration']=movies_df['duration'].astype('int64')

# %%
movies_df.groupby('title')['duration'].max().sort_values(ascending=False).head(10).plot(kind='bar',color='white',edgecolor='red')
plt.title('Movies with longest running time');

# %% [markdown]
# * the movie 'the school of mischief' is the movie with longest duration and 'No longer kids' at the second position

# %%
movies_df.groupby(['director','title'])['duration'].max().sort_values(ascending=False).head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('directors of long duration movies');

# %% [markdown]
# * this graph shows the directors of the movies with longest duration, Houssam El-DIn Mustafa's the school of mischief is the longest followed by other 9 films and their directors

# %%
shows_df=data[data['type']=='TV Show']

# %%
def split(x):
    return x.split(' ')[0]

# %%
shows_df['duration']=shows_df['duration'].apply(split)

# %%
shows_df['duration']=shows_df['duration'].astype('int64')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6824\292702398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shows_df['duration']=shows_df['duration'].astype('int64')

# %%
shows_df.groupby(['title','director'])['duration'].max().sort_values(ascending=False).head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('shows with highest no. seasons and directors');

# %% [markdown]
# * this pie chart plots the shows with longest duration and their directors
# * the show Supernatural by phil sgriccia is the longest with 18.1%

# %%
sns.countplot(x='genre',data=movies_df,color='green')
plt.xticks(rotation=90);
plt.title('Genre Distribution of movies');

# %% [markdown]
# * the movies are more of Drama genres and the least released in LGBTQ genre
# * Comedy, action and adventures are the most shown after Drama genre

# %%
a=shows_df.head(10)
sns.barplot(x='title',y='director',data=a,color='orange');
plt.xticks(rotation=90)
plt.title('directors and their shows');

# %%
movies_df.groupby('genre')['duration'].max().sort_values(ascending=False).head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('time taken by each genres in movies');

# %% [markdown]
# * Majority movie genre in the netflix are Comedies followed by classics and Dramas

# %%
sns.barplot(x='title',y='rating',data=a,color='black')
plt.xticks(rotation=90);

# %%
movies_df['country'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * movies in Netflix are mostly from United states followed by Indian

# %%
shows_df['country'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * United States has less majority in TV shows when compared to movies
# * United Kingdom has the second position in TV shows against the third position in Movies
